# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF # funcion kernel de cov(t, t')
from typing import Callable
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
def omega2():
    k = np.arange(1,21,1)
    return k * 0.2

def s_hat(w):
    return np.exp(- (w * w) / 2) / np.sqrt(2 * np.pi)

def u_bound(w):
    return np.exp(-(w * w)/ 4) * np.sqrt(np.pi)

def func(t, y, w):
    u = y[0]
    v = y[1]
    
    du_dt = v
    dv_dt = w*w * u + np.exp(-(w*w) / 2)

    return [dv_dt , du_dt]

# %%
maxT = 4

omega_vals = omega2()

#Define la condicion inicial de du/dt
v0 = 0

u_four = np.zeros((len(omega_vals),maxT))
#print(u_four)

for i in range(0,len(omega_vals)):

    #Calcula la condicion inicial de u
    u0 = u_bound(w)
    
    #Aplicando RK para resolver la PDE
    R = solve_ivp(lambda t,y: func(t,y,omega_vals[i]), (0, maxT), [u0, v0]).y
    print(R[0])
    print(type(R))
    break
    #u_four[:i] = R[0]
    


#print(u_four)
# Out:
# [[1.75481764 1.87987576 3.16368574 6.31117573]
#  [0.         0.         0.         0.        ]]
# <class 'numpy.ndarray'>
